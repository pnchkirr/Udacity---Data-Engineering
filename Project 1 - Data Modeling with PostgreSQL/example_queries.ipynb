# %% [markdown]
# ### Here are some example queries and results for song play analysis

# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %% [markdown]
# #### 1. Calculate Male to Female ratio amongst Sparkify users

# %%
# %sql \
SELECT \
COUNT(*) FILTER (WHERE gender = 'M') AS male_users, \
COUNT(*) FILTER (WHERE gender = 'F') AS female_users, \
ROUND((COUNT(*) FILTER (WHERE gender = 'M'))::decimal /  \
COUNT(*) FILTER (WHERE gender = 'F'), 2) AS m_f_ratio \
FROM users;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(41, 55, Decimal('0.75'))]

# %% [markdown]
# #### 2. Determine the most popular time of the day (top 5 hours) when users listen to music in Sparkify

# %%
# %sql \
SELECT t.hour, COUNT(*) AS songplays \
FROM songplays sp \
JOIN time t \
ON sp.start_time = t.start_time \
GROUP BY t.hour \
ORDER BY 2 DESC \
LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('16', 542), ('18', 498), ('17', 494), ('15', 477), ('14', 432)]

# %% [markdown]
# #### 3. How many songs do users play within a single session in average?

# %%
# %sql \
WITH songplays_per_session AS \
(SELECT \
user_id, \
session_id, \
COUNT(*) AS songplays \
FROM songplays \
GROUP BY user_id, session_id) \
SELECT CEIL(AVG(songplays)) AS average_songs_per_user_session \
FROM songplays_per_session;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(Decimal('9'),)]

# %% [markdown]
# #### 4. What browsers are the most popular (top 5) amongst Sparkify users?

# %%
# %sql \
SELECT \
user_agent AS browser, \
COUNT(*) AS number_of_users \
FROM songplays \
GROUP BY user_agent \
ORDER BY COUNT(*) DESC \
LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 971),
#  ('"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', 708),
#  ('Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0', 696),
#  ('"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"', 577),
#  ('"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"', 573)]

# %% [markdown]
# #### 5. Count free and paid users per user location

# %%
# %sql \
SELECT sp.location, \
COUNT(*) FILTER (WHERE sp.level = 'free' and u.gender = 'M') AS free_users_male, \
COUNT(*) FILTER (WHERE sp.level = 'free' and u.gender = 'F') AS free_users_female, \
COUNT(*) FILTER (WHERE sp.level = 'free') AS free_users_total, \
COUNT(*) FILTER (WHERE sp.level = 'paid' and u.gender = 'M') AS paid_users_male, \
COUNT(*) FILTER (WHERE sp.level = 'paid' and u.gender = 'F') AS paid_users_female, \
COUNT(*) FILTER (WHERE sp.level = 'paid') AS paid_users \
FROM songplays sp \
JOIN users u \
ON sp.user_id = u.user_id \
GROUP BY sp.location \
ORDER BY 1;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 63 rows affected.
# [('Atlanta-Sandy Springs-Roswell, GA', 0, 28, 28, 0, 428, 428),
#  ('Augusta-Richmond County, GA-SC', 0, 0, 0, 0, 140, 140),
#  ('Birmingham-Hoover, AL', 15, 0, 15, 208, 0, 208),
#  ('Cedar Rapids, IA', 0, 10, 10, 0, 0, 0),
#  ('Chicago-Naperville-Elgin, IL-IN-WI', 0, 13, 13, 0, 462, 462),
#  ('Columbia, SC', 18, 7, 25, 0, 0, 0),
#  ('Dallas-Fort Worth-Arlington, TX', 11, 10, 21, 0, 0, 0),
#  ('Detroit-Warren-Dearborn, MI', 4, 0, 4, 0, 72, 72),
#  ('Elkhart-Goshen, IN', 0, 2, 2, 0, 0, 0),
#  ('Eugene, OR', 20, 0, 20, 0, 0, 0),
#  ('Eureka-Arcata-Fortuna, CA', 16, 0, 16, 0, 0, 0),
#  ('Harrisburg-Carlisle, PA', 37, 0, 37, 0, 0, 0),
#  ('Houston-The Woodlands-Sugar Land, TX', 51, 15, 66, 0, 0, 0),
#  ('Indianapolis-Carmel-Anderson, IN', 0, 14, 14, 0, 0, 0),
#  ('Janesville-Beloit, WI', 7, 0, 7, 241, 0, 241),
#  ('Klamath Falls, OR', 0, 20, 20, 0, 0, 0),
#  ('La Crosse-Onalaska, WI-MN', 45, 0, 45, 0, 0, 0),
#  ('Lake Havasu City-Kingman, AZ', 0, 0, 0, 0, 321, 321),
#  ('Lansing-East Lansing, MI', 0, 0, 0, 0, 557, 557),
#  ('Las Cruces, NM', 0, 6, 6, 0, 0, 0),
#  ('London, KY', 0, 5, 5, 0, 0, 0),
#  ('Longview, TX', 0, 0, 0, 0, 17, 17),
#  ('Los Angeles-Long Beach-Anaheim, CA', 1, 5, 6, 0, 0, 0),
#  ('Lubbock, TX', 0, 27, 27, 0, 0, 0),
#  ('Marinette, WI-MI', 0, 0, 0, 169, 0, 169),
#  ('Miami-Fort Lauderdale-West Palm Beach, FL', 2, 0, 2, 0, 0, 0),
#  ('Milwaukee-Waukesha-West Allis, WI', 0, 9, 9, 0, 0, 0),
#  ('Minneapolis-St. Paul-Bloomington, MN-WI', 15, 0, 15, 0, 0, 0),
#  ('Myrtle Beach-Conway-North Myrtle Beach, SC-NC', 1, 0, 1, 0, 0, 0),
#  ('Nashville-Davidson--Murfreesboro--Franklin, TN', 25, 0, 25, 0, 0, 0),
#  ('New Haven-Milford, CT', 0, 48, 48, 0, 0, 0),
#  ('New Orleans-Metairie, LA', 55, 0, 55, 0, 0, 0),
#  ('New York-Newark-Jersey City, NY-NJ-PA', 49, 64, 113, 149, 0, 149),
#  ('Ogden-Clearfield, UT', 7, 0, 7, 0, 0, 0),
#  ('Oxnard-Thousand Oaks-Ventura, CA', 7, 0, 7, 0, 0, 0),
#  ('Palestine, TX', 0, 27, 27, 0, 0, 0),
#  ('Parkersburg-Vienna, WV', 0, 5, 5, 0, 0, 0),
#  ('Pensacola-Ferry Pass-Brent, FL', 0, 3, 3, 0, 0, 0),
#  ('Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', 0, 35, 35, 0, 0, 0),
#  ('Phoenix-Mesa-Scottsdale, AZ', 0, 27, 27, 0, 0, 0),
#  ('Plymouth, IN', 0, 10, 10, 0, 0, 0),
#  ('Portland-South Portland, ME', 0, 17, 17, 0, 648, 648),
#  ('Portland-Vancouver-Hillsboro, OR-WA', 7, 0, 7, 0, 0, 0),
#  ('Raleigh, NC', 4, 0, 4, 0, 0, 0),
#  ('Red Bluff, CA', 22, 1, 23, 0, 178, 178),
#  ('Richmond, VA', 0, 13, 13, 0, 0, 0),
#  ('Sacramento--Roseville--Arden-Arcade, CA', 29, 0, 29, 241, 0, 241),
#  ('Saginaw, MI', 3, 0, 3, 0, 0, 0),
#  ('Salinas, CA', 0, 37, 37, 0, 0, 0),
#  ('Salt Lake City, UT', 0, 4, 4, 0, 0, 0),
#  ('San Antonio-New Braunfels, TX', 11, 8, 19, 0, 33, 33),
#  ('San Diego-Carlsbad, CA', 5, 0, 5, 0, 0, 0),
#  ('San Francisco-Oakland-Hayward, CA', 2, 39, 41, 0, 650, 650),
#  ('San Jose-Sunnyvale-Santa Clara, CA', 114, 0, 114, 0, 178, 178),
#  ('Santa Rosa, CA', 0, 20, 20, 0, 0, 0),
#  ('Seattle-Tacoma-Bellevue, WA', 0, 14, 14, 0, 0, 0),
#  ('St. Louis, MO-IL', 0, 16, 16, 0, 0, 0),
#  ('Tampa-St. Petersburg-Clearwater, FL', 18, 0, 18, 289, 0, 289),
#  ('Washington-Arlington-Alexandria, DC-VA-MD-WV', 0, 34, 34, 0, 0, 0),
#  ('Waterloo-Cedar Falls, IA', 0, 0, 0, 0, 397, 397),
#  ('Winston-Salem, NC', 0, 0, 0, 0, 213, 213),
#  ('Youngstown-Warren-Boardman, OH-PA', 8, 0, 8, 0, 0, 0),
#  ('Yuba City, CA', 27, 0, 27, 0, 0, 0)]

# %% [markdown]
# The 5 queries above provide examples of the analysis that we can perform on the data we get from Sparkify app.
#
# A few suggestions to make the analysis more insightful are:
# 1. Writing more complex queries (more JOINs).
# 2. Introducing new data like User Age (users table), Genre and Album (songs table), Gender (artitsts table).
